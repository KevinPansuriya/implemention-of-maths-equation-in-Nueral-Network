# %%
import pandas as pd
import numpy as np


df = pd.read_csv('W1data.csv')
df.head()
# Out:
#     Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0  1.518613   -0.562250  0.232053          -1.169593   1.913905
# 1  0.246290   -0.499413 -0.827996          -2.490847   0.018145
# 2  0.196879    0.021231  1.109334          -0.268738   0.088358
# 3  1.691550   -0.346811  0.487926          -0.809251   0.930918
# 4  0.295700    0.227694  1.840403           0.451946   1.281985
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0       0.808997    1.034819             -0.659563         1.224884
# 1       0.568648    0.733629             -0.820719        -0.544721
# 2       0.808997    1.215533             -0.498407         2.135968
# 3       2.491446    1.466525             -0.981875         1.032155
# 4       0.808997    0.663351              0.226796         0.401404
#
#    Color intensity       Hue  OD280/OD315 of diluted wines   Proline  \
# 0         0.251717  0.362177                      1.847920  1.013009
# 1        -0.293321  0.406051                      1.113449  0.965242
# 2         0.269020  0.318304                      0.788587  1.395148
# 3         1.186068 -0.427544                      1.184071  2.334574
# 4        -0.319276  0.362177                      0.449601 -0.037874
#
#    Cultivar 1  Cultivar 2  Cultivar 3
# 0           1           0           0
# 1           1           0           0
# 2           1           0           0
# 3           1           0           0
# 4           1           0           0

# %%
# Get the wine labels
y = df[['Cultivar 1', 'Cultivar 2', 'Cultivar 3']].values

# Get inputs; we define our x and y here.
X = df.drop(['Cultivar 1', 'Cultivar 2', 'Cultivar 3'], axis = 1)
X.shape, y.shape # Print shapes just to check
X = X.values

# %%
#First we are importing all the libraries

# Package imports
# Matplotlib is a matlab like plotting library
import matplotlib
import matplotlib.pyplot as plt
# SciKitLearn is a useful machine learning utilities library
import sklearn
# The sklearn dataset module helps generating datasets
import sklearn.datasets
import sklearn.linear_model
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score

# %%
def softmax(z):
    #Calculate exponent term first
    exp_scores = np.exp(z)
    return exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

def softmax_loss(y,y_hat):
    # Clipping value
    minval = 0.000000000001
    # Number of samples
    m = y.shape[0]
    # Loss formula, note that np.sum sums up the entire matrix and therefore does the job of two sums from the formula
    loss = -1/m * np.sum(y * np.log(y_hat.clip(min=minval)))
    return loss

# %%
def loss_derivative(y,y_hat):
    return (y_hat-y)

def tanh_derivative(x):
    return (1 - np.power(x, 2))

np.random.seed(0)

# %%
def forward_prop(model,a0):

    
    # Load parameters from model
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'], model['W3'],model['b3']
    
    # Do the first Linear step 
    # Z1 is the input layer x times the dot product of the weights + our bias b
    z1 = a0.dot(W1) + b1
    
    # Put it through the first activation function
    a1 = np.tanh(z1)
    
    # Second linear step
    z2 = a1.dot(W2) + b2
    
    # Second activation function
    a2 = np.tanh(z2)
    
    #Third linear step
    z3 = a2.dot(W3) + b3
    
    #For the Third linear activation function we use the softmax function, either the sigmoid of softmax should be used for the last layer
    a3 = softmax(z3)
    cache = {'a0':a0,'z1':z1,'a1':a1,'z2':z2,'a2':a2,'a3':a3,'z3':z3}
    return cache

# %%
def backward_prop(model,cache,y):

    # Load parameters from model
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'],model['W3'],model['b3']
    
    # Load forward propagation results
    a0,a1, a2,a3 = cache['a0'],cache['a1'],cache['a2'],cache['a3']
    
    # Get number of samples
    m = y.shape[0]
    
    # Calculate loss derivative with respect to output
    dz3 = loss_derivative(y=y,y_hat=a3)

    # Calculate loss derivative with respect to second layer weights
    dW3 = 1/m*(a2.T).dot(dz3) #dW2 = 1/m*(a1.T).dot(dz2) 
    
    # Calculate loss derivative with respect to second layer bias
    db3 = 1/m*np.sum(dz3, axis=0)
    
    # Calculate loss derivative with respect to first layer
    dz2 = np.multiply(dz3.dot(W3.T) ,tanh_derivative(a2))
    
    # Calculate loss derivative with respect to first layer weights
    dW2 = 1/m*np.dot(a1.T, dz2)
    
    # Calculate loss derivative with respect to first layer bias
    db2 = 1/m*np.sum(dz2, axis=0)
    
    dz1 = np.multiply(dz2.dot(W2.T),tanh_derivative(a1))
    
    dW1 = 1/m*np.dot(a0.T,dz1)
    
    db1 = 1/m*np.sum(dz1,axis=0)
    
    # Store gradients
    grads = {'dW3':dW3, 'db3':db3, 'dW2':dW2,'db2':db2,'dW1':dW1,'db1':db1}
    return grads

# %%
def initialize_parameters(nn_input_dim,nn_hdim,nn_output_dim):
    # First layer weights
    W1 = 2 *np.random.randn(nn_input_dim, nn_hdim) - 1
    
    # First layer bias
    b1 = np.zeros((1, nn_hdim))
    
    # Second layer weights
    W2 = 2 * np.random.randn(nn_hdim, nn_hdim) - 1
    
    # Second layer bias
    b2 = np.zeros((1, nn_hdim))
    W3 = 2 * np.random.rand(nn_hdim, nn_output_dim) - 1
    b3 = np.zeros((1,nn_output_dim))
    
    
    # Package and return model
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2,'W3':W3,'b3':b3}
    return model

# %%
def update_parameters(model,grads,learning_rate):
    # Load parameters
    W1, b1, W2, b2,b3,W3 = model['W1'], model['b1'], model['W2'], model['b2'],model['b3'],model["W3"]
    
    # Update parameters
    W1 -= learning_rate * grads['dW1']
    b1 -= learning_rate * grads['db1']
    W2 -= learning_rate * grads['dW2']
    b2 -= learning_rate * grads['db2']
    W3 -= learning_rate * grads['dW3']
    b3 -= learning_rate * grads['db3']
    
    # Store and return parameters
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2, 'W3':W3,'b3':b3}
    return model

# %%
def predict(model, x):
    # Do forward pass
    c = forward_prop(model,x)
    #get y_hat
    y_hat = np.argmax(c['a3'], axis=1)
    return y_hat

# %%
def calc_accuracy(model,x,y):
    # Get total number of examples
    m = y.shape[0]
    # Do a prediction with the model
    pred = predict(model,x)
    # Ensure prediction and truth vector y have the same shape
    pred = pred.reshape(y.shape)
    # Calculate the number of wrong examples
    error = np.sum(np.abs(pred-y))
    # Calculate accuracy
    return (m - error)/m * 100
losses = []

# %%
def train(model,X_,y_,learning_rate, epochs=20000, print_loss=False):
    # Gradient descent. Loop over epochs
    for i in range(0, epochs):
        

        # Forward propagation
        cache = forward_prop(model,X_)
        #a1, probs = cache['a1'],cache['a2']
        # Backpropagation
        
        grads = backward_prop(model,cache,y_)
        # Gradient descent parameter update
        # Assign new parameters to the model
        model = update_parameters(model=model,grads=grads,learning_rate=learning_rate)
    
        # Pring loss & accuracy every 100 iterations
        if print_loss and i % 100 == 0:
            a3 = cache['a3']
            print('Loss after iteration',i,':',softmax_loss(y_,a3))
            y_hat = predict(model,X_)
            y_true = y_.argmax(axis=1)
            
            print('Accuracy after iteration',i,':',accuracy_score(y_pred=y_hat,y_true=y_true)*100,'%')
            losses.append(accuracy_score(y_pred=y_hat,y_true=y_true)*100)
    return model

# %%
model = initialize_parameters(nn_input_dim=13, nn_hdim= 5, nn_output_dim= 3)
model = train(model,X,y,learning_rate=0.07,epochs=20000,print_loss=True)
plt.plot(losses)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7c2c28e9c3c1> in <module>
# ----> 1 model = initialize_parameters(nn_input_dim=13, nn_hdim= 5, nn_output_dim= 3)
#       2 model = train(model,X,y,learning_rate=0.07,epochs=20000,print_loss=True)
#       3 plt.plot(losses)
#
# NameError: name 'initialize_parameters' is not defined

# %%
import numpy as np

def sigmoid(x):
  # Sigmoid activation function: f(x) = 1 / (1 + e^(-x))
  return 1 / (1 + np.exp(-x))

def deriv_sigmoid(x):
  # Derivative of sigmoid: f'(x) = f(x) * (1 - f(x))
  fx = sigmoid(x)
  return fx * (1 - fx)

def mse_loss(y_true, y_pred):
  # y_true and y_pred are numpy arrays of the same length.
  return ((y_true - y_pred) ** 2).mean()

class OurNeuralNetwork:
  '''
  A neural network with:
    - 2 inputs
    - a hidden layer with 2 neurons (h1, h2)
    - an output layer with 1 neuron (o1)

  *** DISCLAIMER ***:
  The code below is intended to be simple and educational, NOT optimal.
  Real neural net code looks nothing like this. DO NOT use this code.
  Instead, read/run it to understand how this specific network works.
  '''
  def __init__(self):
    # Weights
    self.w1 = np.random.normal()
    self.w2 = np.random.normal()
    self.w3 = np.random.normal()
    self.w4 = np.random.normal()
    self.w5 = np.random.normal()
    self.w6 = np.random.normal()

    # Biases
    self.b1 = np.random.normal()
    self.b2 = np.random.normal()
    self.b3 = np.random.normal()

  def feedforward(self, x):
    # x is a numpy array with 2 elements.
    h1 = sigmoid(self.w1 * x[0] + self.w2 * x[1] + self.b1)
    h2 = sigmoid(self.w3 * x[0] + self.w4 * x[1] + self.b2)
    o1 = sigmoid(self.w5 * h1 + self.w6 * h2 + self.b3)
    return o1

  def train(self, data, all_y_trues):
    '''
    - data is a (n x 2) numpy array, n = # of samples in the dataset.
    - all_y_trues is a numpy array with n elements.
      Elements in all_y_trues correspond to those in data.
    '''
    learn_rate = 0.1
    epochs = 10000 # number of times to loop through the entire dataset

    for epoch in range(epochs):
      for x, y_true in zip(data, all_y_trues):
        # --- Do a feedforward (we'll need these values later)
        sum_h1 = self.w1 * x[0] + self.w2 * x[1] + self.b1
        h1 = sigmoid(sum_h1)

        sum_h2 = self.w3 * x[0] + self.w4 * x[1] + self.b2
        h2 = sigmoid(sum_h2)

        sum_o1 = self.w5 * h1 + self.w6 * h2 + self.b3
        o1 = sigmoid(sum_o1)
        y_pred = o1

        # --- Calculate partial derivatives.
        # --- Naming: d_L_d_w1 represents "partial L / partial w1"
        d_L_d_ypred = -2 * (y_true - y_pred)

        # Neuron o1
        d_ypred_d_w5 = h1 * deriv_sigmoid(sum_o1)
        d_ypred_d_w6 = h2 * deriv_sigmoid(sum_o1)
        d_ypred_d_b3 = deriv_sigmoid(sum_o1)

        d_ypred_d_h1 = self.w5 * deriv_sigmoid(sum_o1)
        d_ypred_d_h2 = self.w6 * deriv_sigmoid(sum_o1)

        # Neuron h1
        d_h1_d_w1 = x[0] * deriv_sigmoid(sum_h1)
        d_h1_d_w2 = x[1] * deriv_sigmoid(sum_h1)
        d_h1_d_b1 = deriv_sigmoid(sum_h1)

        # Neuron h2
        d_h2_d_w3 = x[0] * deriv_sigmoid(sum_h2)
        d_h2_d_w4 = x[1] * deriv_sigmoid(sum_h2)
        d_h2_d_b2 = deriv_sigmoid(sum_h2)

        # --- Update weights and biases
        # Neuron h1
        self.w1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w1
        self.w2 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w2
        self.b1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_b1

        # Neuron h2
        self.w3 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w3
        self.w4 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w4
        self.b2 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_b2

        # Neuron o1
        self.w5 -= learn_rate * d_L_d_ypred * d_ypred_d_w5
        self.w6 -= learn_rate * d_L_d_ypred * d_ypred_d_w6
        self.b3 -= learn_rate * d_L_d_ypred * d_ypred_d_b3

      # --- Calculate total loss at the end of each epoch
      if epoch % 10 == 0:
        y_preds = np.apply_along_axis(self.feedforward, 1, data)
        loss = mse_loss(all_y_trues, y_preds)
        print("Epoch %d loss: %.3f" % (epoch, loss))

# Define dataset
data = np.array([
  [21, 1],  # Alice
  [52, 16],   # Bob
  [27, 34],   # Charlie
  [5, 6], # Diana
])
all_y_trues = np.array([
  1, # Alice
  0, # Bob
  0, # Charlie
  1, # Diana
])

# Train our neural network!
network = OurNeuralNetwork()
network.train(data, all_y_trues)

# Make some predictions
emily = np.array([7, 3]) # 128 pounds, 63 inches
frank = np.array([2, 2])  # 155 pounds, 68 inches
print("Emily: %.3f" % network.feedforward(emily)) # 0.951 - F
print("Frank: %.3f" % network.feedforward(frank)) # 0.039 - M
# Out:
# Epoch 0 loss: 0.303
# Epoch 10 loss: 0.255
# Epoch 20 loss: 0.227
# Epoch 30 loss: 0.211
# Epoch 40 loss: 0.202
# Epoch 50 loss: 0.197
# Epoch 60 loss: 0.193
# Epoch 70 loss: 0.190
# Epoch 80 loss: 0.187
# Epoch 90 loss: 0.185
# Epoch 100 loss: 0.183
# Epoch 110 loss: 0.182
# Epoch 120 loss: 0.180
# Epoch 130 loss: 0.179
# Epoch 140 loss: 0.178
# Epoch 150 loss: 0.177
# Epoch 160 loss: 0.177
# Epoch 170 loss: 0.176
# Epoch 180 loss: 0.175
# Epoch 190 loss: 0.175
# Epoch 200 loss: 0.174
# Epoch 210 loss: 0.174
# Epoch 220 loss: 0.173
# Epoch 230 loss: 0.173
# Epoch 240 loss: 0.173
# Epoch 250 loss: 0.172
# Epoch 260 loss: 0.172
# Epoch 270 loss: 0.172
# Epoch 280 loss: 0.172
# Epoch 290 loss: 0.171
# Epoch 300 loss: 0.171
# Epoch 310 loss: 0.171
# Epoch 320 loss: 0.171
# Epoch 330 loss: 0.171
# Epoch 340 loss: 0.170
# Epoch 350 loss: 0.170
# Epoch 360 loss: 0.170
# Epoch 370 loss: 0.170
# Epoch 380 loss: 0.170
# Epoch 390 loss: 0.170
# Epoch 400 loss: 0.170
# Epoch 410 loss: 0.170
# Epoch 420 loss: 0.170
# Epoch 430 loss: 0.169
# Epoch 440 loss: 0.169
# Epoch 450 loss: 0.169
# Epoch 460 loss: 0.169
# Epoch 470 loss: 0.169
# Epoch 480 loss: 0.169
# Epoch 490 loss: 0.169
# Epoch 500 loss: 0.169
# Epoch 510 loss: 0.169
# Epoch 520 loss: 0.169
# Epoch 530 loss: 0.169
# Epoch 540 loss: 0.169
# Epoch 550 loss: 0.169
# Epoch 560 loss: 0.169
# Epoch 570 loss: 0.169
# Epoch 580 loss: 0.169
# Epoch 590 loss: 0.169
# Epoch 600 loss: 0.168
# Epoch 610 loss: 0.168
# Epoch 620 loss: 0.168
# Epoch 630 loss: 0.168
# Epoch 640 loss: 0.168
# Epoch 650 loss: 0.168
# Epoch 660 loss: 0.168
# Epoch 670 loss: 0.168
# Epoch 680 loss: 0.168
# Epoch 690 loss: 0.168
# Epoch 700 loss: 0.168
# Epoch 710 loss: 0.168
# Epoch 720 loss: 0.168
# Epoch 730 loss: 0.168
# Epoch 740 loss: 0.168
# Epoch 750 loss: 0.168
# Epoch 760 loss: 0.168
# Epoch 770 loss: 0.168
# Epoch 780 loss: 0.168
# Epoch 790 loss: 0.168
# Epoch 800 loss: 0.168
# Epoch 810 loss: 0.168
# Epoch 820 loss: 0.168
# Epoch 830 loss: 0.168
# Epoch 840 loss: 0.168
# Epoch 850 loss: 0.168
# Epoch 860 loss: 0.168
# Epoch 870 loss: 0.168
# Epoch 880 loss: 0.168
# Epoch 890 loss: 0.168
# Epoch 900 loss: 0.168
# Epoch 910 loss: 0.168
# Epoch 920 loss: 0.168
# Epoch 930 loss: 0.168
# Epoch 940 loss: 0.168
# Epoch 950 loss: 0.168
# Epoch 960 loss: 0.168
# Epoch 970 loss: 0.168
# Epoch 980 loss: 0.168
# Epoch 990 loss: 0.168
# Epoch 1000 loss: 0.168
# Epoch 1010 loss: 0.168
# Epoch 1020 loss: 0.168
# Epoch 1030 loss: 0.168
# Epoch 1040 loss: 0.168
# Epoch 1050 loss: 0.168
# Epoch 1060 loss: 0.168
# Epoch 1070 loss: 0.168
# Epoch 1080 loss: 0.168
# Epoch 1090 loss: 0.168
# Epoch 1100 loss: 0.168
# Epoch 1110 loss: 0.168
# Epoch 1120 loss: 0.168
# Epoch 1130 loss: 0.168
# Epoch 1140 loss: 0.167
# Epoch 1150 loss: 0.167
# Epoch 1160 loss: 0.167
# Epoch 1170 loss: 0.167
# Epoch 1180 loss: 0.167
# Epoch 1190 loss: 0.167
# Epoch 1200 loss: 0.167
# Epoch 1210 loss: 0.167
# Epoch 1220 loss: 0.167
# Epoch 1230 loss: 0.167
# Epoch 1240 loss: 0.167
# Epoch 1250 loss: 0.167
# Epoch 1260 loss: 0.167
# Epoch 1270 loss: 0.167
# Epoch 1280 loss: 0.167
# Epoch 1290 loss: 0.167
# Epoch 1300 loss: 0.167
# Epoch 1310 loss: 0.167
# Epoch 1320 loss: 0.167
# Epoch 1330 loss: 0.167
# Epoch 1340 loss: 0.167
# Epoch 1350 loss: 0.167
# Epoch 1360 loss: 0.167
# Epoch 1370 loss: 0.167
# Epoch 1380 loss: 0.167
# Epoch 1390 loss: 0.167
# Epoch 1400 loss: 0.167
# Epoch 1410 loss: 0.167
# Epoch 1420 loss: 0.167
# Epoch 1430 loss: 0.167
# Epoch 1440 loss: 0.167
# Epoch 1450 loss: 0.167
# Epoch 1460 loss: 0.167
# Epoch 1470 loss: 0.167
# Epoch 1480 loss: 0.167
# Epoch 1490 loss: 0.167
# Epoch 1500 loss: 0.167
# Epoch 1510 loss: 0.167
# Epoch 1520 loss: 0.167
# Epoch 1530 loss: 0.167
# Epoch 1540 loss: 0.167
# Epoch 1550 loss: 0.167
# Epoch 1560 loss: 0.167
# Epoch 1570 loss: 0.167
# Epoch 1580 loss: 0.167
# Epoch 1590 loss: 0.167
# Epoch 1600 loss: 0.167
# Epoch 1610 loss: 0.167
# Epoch 1620 loss: 0.167
# Epoch 1630 loss: 0.167
# Epoch 1640 loss: 0.167
# Epoch 1650 loss: 0.167
# Epoch 1660 loss: 0.167
# Epoch 1670 loss: 0.167
# Epoch 1680 loss: 0.167
# Epoch 1690 loss: 0.167
# Epoch 1700 loss: 0.167
# Epoch 1710 loss: 0.167
# Epoch 1720 loss: 0.167
# Epoch 1730 loss: 0.167
# Epoch 1740 loss: 0.167
# Epoch 1750 loss: 0.167
# Epoch 1760 loss: 0.167
# Epoch 1770 loss: 0.167
# Epoch 1780 loss: 0.167
# Epoch 1790 loss: 0.167
# Epoch 1800 loss: 0.167
# Epoch 1810 loss: 0.167
# Epoch 1820 loss: 0.167
# Epoch 1830 loss: 0.167
# Epoch 1840 loss: 0.167
# Epoch 1850 loss: 0.167
# Epoch 1860 loss: 0.167
# Epoch 1870 loss: 0.167
# Epoch 1880 loss: 0.167
# Epoch 1890 loss: 0.167
# Epoch 1900 loss: 0.167
# Epoch 1910 loss: 0.167
# Epoch 1920 loss: 0.167
# Epoch 1930 loss: 0.167
# Epoch 1940 loss: 0.167
# Epoch 1950 loss: 0.167
# Epoch 1960 loss: 0.167
# Epoch 1970 loss: 0.167
# Epoch 1980 loss: 0.167
# Epoch 1990 loss: 0.167
# Epoch 2000 loss: 0.167
# Epoch 2010 loss: 0.167
# Epoch 2020 loss: 0.167
# Epoch 2030 loss: 0.167
# Epoch 2040 loss: 0.167
# Epoch 2050 loss: 0.167
# Epoch 2060 loss: 0.167
# Epoch 2070 loss: 0.167
# Epoch 2080 loss: 0.167
# Epoch 2090 loss: 0.167
# Epoch 2100 loss: 0.167
# Epoch 2110 loss: 0.167
# Epoch 2120 loss: 0.167
# Epoch 2130 loss: 0.167
# Epoch 2140 loss: 0.167
# Epoch 2150 loss: 0.167
# Epoch 2160 loss: 0.167
# Epoch 2170 loss: 0.167
# Epoch 2180 loss: 0.167
# Epoch 2190 loss: 0.167
# Epoch 2200 loss: 0.167
# Epoch 2210 loss: 0.167
# Epoch 2220 loss: 0.167
# Epoch 2230 loss: 0.167
# Epoch 2240 loss: 0.167
# Epoch 2250 loss: 0.167
# Epoch 2260 loss: 0.167
# Epoch 2270 loss: 0.167
# Epoch 2280 loss: 0.167
# Epoch 2290 loss: 0.167
# Epoch 2300 loss: 0.167
# Epoch 2310 loss: 0.167
# Epoch 2320 loss: 0.167
# Epoch 2330 loss: 0.167
# Epoch 2340 loss: 0.167
# Epoch 2350 loss: 0.167
# Epoch 2360 loss: 0.167
# Epoch 2370 loss: 0.167
# Epoch 2380 loss: 0.167
# Epoch 2390 loss: 0.167
# Epoch 2400 loss: 0.167
# Epoch 2410 loss: 0.167
# Epoch 2420 loss: 0.167
# Epoch 2430 loss: 0.167
# Epoch 2440 loss: 0.167
# Epoch 2450 loss: 0.167
# Epoch 2460 loss: 0.167
# Epoch 2470 loss: 0.167
# Epoch 2480 loss: 0.167
# Epoch 2490 loss: 0.167
# Epoch 2500 loss: 0.167
# Epoch 2510 loss: 0.167
# Epoch 2520 loss: 0.167
# Epoch 2530 loss: 0.167
# Epoch 2540 loss: 0.167
# Epoch 2550 loss: 0.167
# Epoch 2560 loss: 0.167
# Epoch 2570 loss: 0.167
# Epoch 2580 loss: 0.167
# Epoch 2590 loss: 0.167
# Epoch 2600 loss: 0.167
# Epoch 2610 loss: 0.167
# Epoch 2620 loss: 0.167
# Epoch 2630 loss: 0.167
# Epoch 2640 loss: 0.167
# Epoch 2650 loss: 0.167
# Epoch 2660 loss: 0.167
# Epoch 2670 loss: 0.167
# Epoch 2680 loss: 0.167
# Epoch 2690 loss: 0.167
# Epoch 2700 loss: 0.167
# Epoch 2710 loss: 0.167
# Epoch 2720 loss: 0.167
# Epoch 2730 loss: 0.167
# Epoch 2740 loss: 0.167
# Epoch 2750 loss: 0.167
# Epoch 2760 loss: 0.167
# Epoch 2770 loss: 0.167
# Epoch 2780 loss: 0.167
# Epoch 2790 loss: 0.167
# Epoch 2800 loss: 0.167
# Epoch 2810 loss: 0.167
# Epoch 2820 loss: 0.167
# Epoch 2830 loss: 0.167
# Epoch 2840 loss: 0.167
# Epoch 2850 loss: 0.167
# Epoch 2860 loss: 0.167
# Epoch 2870 loss: 0.167
# Epoch 2880 loss: 0.167
# Epoch 2890 loss: 0.167
# Epoch 2900 loss: 0.167
# Epoch 2910 loss: 0.167
# Epoch 2920 loss: 0.167
# Epoch 2930 loss: 0.167
# Epoch 2940 loss: 0.167
# Epoch 2950 loss: 0.167
# Epoch 2960 loss: 0.167
# Epoch 2970 loss: 0.167
# Epoch 2980 loss: 0.167
# Epoch 2990 loss: 0.167
# Epoch 3000 loss: 0.167
# Epoch 3010 loss: 0.167
# Epoch 3020 loss: 0.167
# Epoch 3030 loss: 0.167
# Epoch 3040 loss: 0.167
# Epoch 3050 loss: 0.167
# Epoch 3060 loss: 0.167
# Epoch 3070 loss: 0.167
# Epoch 3080 loss: 0.167
# Epoch 3090 loss: 0.167
# Epoch 3100 loss: 0.167
# Epoch 3110 loss: 0.167
# Epoch 3120 loss: 0.167
# Epoch 3130 loss: 0.167
# Epoch 3140 loss: 0.167
# Epoch 3150 loss: 0.167
# Epoch 3160 loss: 0.167
# Epoch 3170 loss: 0.167
# Epoch 3180 loss: 0.167
# Epoch 3190 loss: 0.167
# Epoch 3200 loss: 0.167
# Epoch 3210 loss: 0.167
# Epoch 3220 loss: 0.167
# Epoch 3230 loss: 0.167
# Epoch 3240 loss: 0.167
# Epoch 3250 loss: 0.167
# Epoch 3260 loss: 0.167
# Epoch 3270 loss: 0.167
# Epoch 3280 loss: 0.167
# Epoch 3290 loss: 0.167
# Epoch 3300 loss: 0.167
# Epoch 3310 loss: 0.167
# Epoch 3320 loss: 0.167
# Epoch 3330 loss: 0.167
# Epoch 3340 loss: 0.167
# Epoch 3350 loss: 0.167
# Epoch 3360 loss: 0.167
# Epoch 3370 loss: 0.167
# Epoch 3380 loss: 0.167
# Epoch 3390 loss: 0.167
# Epoch 3400 loss: 0.167
# Epoch 3410 loss: 0.167
# Epoch 3420 loss: 0.167
# Epoch 3430 loss: 0.167
# Epoch 3440 loss: 0.167
# Epoch 3450 loss: 0.167
# Epoch 3460 loss: 0.167
# Epoch 3470 loss: 0.167
# Epoch 3480 loss: 0.167
# Epoch 3490 loss: 0.167
# Epoch 3500 loss: 0.167
# Epoch 3510 loss: 0.167
# Epoch 3520 loss: 0.167
# Epoch 3530 loss: 0.167
# Epoch 3540 loss: 0.167
# Epoch 3550 loss: 0.167
# Epoch 3560 loss: 0.167
# Epoch 3570 loss: 0.167
# Epoch 3580 loss: 0.167
# Epoch 3590 loss: 0.167
# Epoch 3600 loss: 0.167
# Epoch 3610 loss: 0.167
# Epoch 3620 loss: 0.167
# Epoch 3630 loss: 0.167
# Epoch 3640 loss: 0.167
# Epoch 3650 loss: 0.167
# Epoch 3660 loss: 0.167
# Epoch 3670 loss: 0.167
# Epoch 3680 loss: 0.167
# Epoch 3690 loss: 0.167
# Epoch 3700 loss: 0.167
# Epoch 3710 loss: 0.167
# Epoch 3720 loss: 0.167
# Epoch 3730 loss: 0.167
# Epoch 3740 loss: 0.167
# Epoch 3750 loss: 0.167
# Epoch 3760 loss: 0.167
# Epoch 3770 loss: 0.167
# Epoch 3780 loss: 0.167
# Epoch 3790 loss: 0.167
# Epoch 3800 loss: 0.167
# Epoch 3810 loss: 0.167
# Epoch 3820 loss: 0.167
# Epoch 3830 loss: 0.167
# Epoch 3840 loss: 0.167
# Epoch 3850 loss: 0.167
# Epoch 3860 loss: 0.167
# Epoch 3870 loss: 0.167
# Epoch 3880 loss: 0.167
# Epoch 3890 loss: 0.167
# Epoch 3900 loss: 0.167
# Epoch 3910 loss: 0.167
# Epoch 3920 loss: 0.167
# Epoch 3930 loss: 0.167
# Epoch 3940 loss: 0.167
# Epoch 3950 loss: 0.167
# Epoch 3960 loss: 0.167
# Epoch 3970 loss: 0.167
# Epoch 3980 loss: 0.167
# Epoch 3990 loss: 0.167
# Epoch 4000 loss: 0.167
# Epoch 4010 loss: 0.167
# Epoch 4020 loss: 0.167
# Epoch 4030 loss: 0.167
# Epoch 4040 loss: 0.167
# Epoch 4050 loss: 0.167
# Epoch 4060 loss: 0.167
# Epoch 4070 loss: 0.167
# Epoch 4080 loss: 0.167
# Epoch 4090 loss: 0.167
# Epoch 4100 loss: 0.167
# Epoch 4110 loss: 0.167
# Epoch 4120 loss: 0.167
# Epoch 4130 loss: 0.167
# Epoch 4140 loss: 0.167
# Epoch 4150 loss: 0.167
# Epoch 4160 loss: 0.167
# Epoch 4170 loss: 0.167
# Epoch 4180 loss: 0.167
# Epoch 4190 loss: 0.167
# Epoch 4200 loss: 0.167
# Epoch 4210 loss: 0.167
# Epoch 4220 loss: 0.167
# Epoch 4230 loss: 0.167
# Epoch 4240 loss: 0.167
# Epoch 4250 loss: 0.167
# Epoch 4260 loss: 0.167
# Epoch 4270 loss: 0.167
# Epoch 4280 loss: 0.167
# Epoch 4290 loss: 0.167
# Epoch 4300 loss: 0.167
# Epoch 4310 loss: 0.167
# Epoch 4320 loss: 0.167
# Epoch 4330 loss: 0.167
# Epoch 4340 loss: 0.167
# Epoch 4350 loss: 0.167
# Epoch 4360 loss: 0.167
# Epoch 4370 loss: 0.167
# Epoch 4380 loss: 0.167
# Epoch 4390 loss: 0.167
# Epoch 4400 loss: 0.167
# Epoch 4410 loss: 0.167
# Epoch 4420 loss: 0.167
# Epoch 4430 loss: 0.167
# Epoch 4440 loss: 0.167
# Epoch 4450 loss: 0.167
# Epoch 4460 loss: 0.167
# Epoch 4470 loss: 0.167
# Epoch 4480 loss: 0.167
# Epoch 4490 loss: 0.167
# Epoch 4500 loss: 0.167
# Epoch 4510 loss: 0.167
# Epoch 4520 loss: 0.167
# Epoch 4530 loss: 0.167
# Epoch 4540 loss: 0.167
# Epoch 4550 loss: 0.167
# Epoch 4560 loss: 0.167
# Epoch 4570 loss: 0.167
# Epoch 4580 loss: 0.167
# Epoch 4590 loss: 0.167
# Epoch 4600 loss: 0.167
# Epoch 4610 loss: 0.167
# Epoch 4620 loss: 0.167
# Epoch 4630 loss: 0.167
# Epoch 4640 loss: 0.167
# Epoch 4650 loss: 0.167
# Epoch 4660 loss: 0.167
# Epoch 4670 loss: 0.167
# Epoch 4680 loss: 0.167
# Epoch 4690 loss: 0.167
# Epoch 4700 loss: 0.167
# Epoch 4710 loss: 0.167
# Epoch 4720 loss: 0.167
# Epoch 4730 loss: 0.167
# Epoch 4740 loss: 0.167
# Epoch 4750 loss: 0.167
# Epoch 4760 loss: 0.167
# Epoch 4770 loss: 0.167
# Epoch 4780 loss: 0.167
# Epoch 4790 loss: 0.167
# Epoch 4800 loss: 0.167
# Epoch 4810 loss: 0.167
# Epoch 4820 loss: 0.167
# Epoch 4830 loss: 0.167
# Epoch 4840 loss: 0.167
# Epoch 4850 loss: 0.167
# Epoch 4860 loss: 0.167
# Epoch 4870 loss: 0.167
# Epoch 4880 loss: 0.167
# Epoch 4890 loss: 0.167
# Epoch 4900 loss: 0.167
# Epoch 4910 loss: 0.167
# Epoch 4920 loss: 0.167
# Epoch 4930 loss: 0.167
# Epoch 4940 loss: 0.167
# Epoch 4950 loss: 0.167
# Epoch 4960 loss: 0.167
# Epoch 4970 loss: 0.167
# Epoch 4980 loss: 0.167
# Epoch 4990 loss: 0.167
# Epoch 5000 loss: 0.167
# Epoch 5010 loss: 0.167
# Epoch 5020 loss: 0.167
# Epoch 5030 loss: 0.167
# Epoch 5040 loss: 0.167
# Epoch 5050 loss: 0.167
# Epoch 5060 loss: 0.167
# Epoch 5070 loss: 0.167
# Epoch 5080 loss: 0.167
# Epoch 5090 loss: 0.167
# Epoch 5100 loss: 0.167
# Epoch 5110 loss: 0.167
# Epoch 5120 loss: 0.167
# Epoch 5130 loss: 0.167
# Epoch 5140 loss: 0.167
# Epoch 5150 loss: 0.167
# Epoch 5160 loss: 0.167
# Epoch 5170 loss: 0.167
# Epoch 5180 loss: 0.167
# Epoch 5190 loss: 0.167
# Epoch 5200 loss: 0.167
# Epoch 5210 loss: 0.167
# Epoch 5220 loss: 0.167
# Epoch 5230 loss: 0.167
# Epoch 5240 loss: 0.167
# Epoch 5250 loss: 0.167
# Epoch 5260 loss: 0.167
# Epoch 5270 loss: 0.167
# Epoch 5280 loss: 0.167
# Epoch 5290 loss: 0.167
# Epoch 5300 loss: 0.167
# Epoch 5310 loss: 0.167
# Epoch 5320 loss: 0.167
# Epoch 5330 loss: 0.167
# Epoch 5340 loss: 0.167
# Epoch 5350 loss: 0.167
# Epoch 5360 loss: 0.167
# Epoch 5370 loss: 0.167
# Epoch 5380 loss: 0.167
# Epoch 5390 loss: 0.167
# Epoch 5400 loss: 0.167
# Epoch 5410 loss: 0.167
# Epoch 5420 loss: 0.167
# Epoch 5430 loss: 0.167
# Epoch 5440 loss: 0.167
# Epoch 5450 loss: 0.167
# Epoch 5460 loss: 0.167
# Epoch 5470 loss: 0.167
# Epoch 5480 loss: 0.167
# Epoch 5490 loss: 0.167
# Epoch 5500 loss: 0.167
# Epoch 5510 loss: 0.167
# Epoch 5520 loss: 0.167
# Epoch 5530 loss: 0.167
# Epoch 5540 loss: 0.167
# Epoch 5550 loss: 0.167
# Epoch 5560 loss: 0.167
# Epoch 5570 loss: 0.167
# Epoch 5580 loss: 0.167
# Epoch 5590 loss: 0.167
# Epoch 5600 loss: 0.167
# Epoch 5610 loss: 0.167
# Epoch 5620 loss: 0.167
# Epoch 5630 loss: 0.167
# Epoch 5640 loss: 0.167
# Epoch 5650 loss: 0.167
# Epoch 5660 loss: 0.167
# Epoch 5670 loss: 0.167
# Epoch 5680 loss: 0.167
# Epoch 5690 loss: 0.167
# Epoch 5700 loss: 0.167
# Epoch 5710 loss: 0.167
# Epoch 5720 loss: 0.167
# Epoch 5730 loss: 0.167
# Epoch 5740 loss: 0.167
# Epoch 5750 loss: 0.167
# Epoch 5760 loss: 0.167
# Epoch 5770 loss: 0.167
# Epoch 5780 loss: 0.167
# Epoch 5790 loss: 0.167
# Epoch 5800 loss: 0.167
# Epoch 5810 loss: 0.167
# Epoch 5820 loss: 0.167
# Epoch 5830 loss: 0.167
# Epoch 5840 loss: 0.167
# Epoch 5850 loss: 0.167
# Epoch 5860 loss: 0.167
# Epoch 5870 loss: 0.167
# Epoch 5880 loss: 0.167
# Epoch 5890 loss: 0.167
# Epoch 5900 loss: 0.167
# Epoch 5910 loss: 0.167
# Epoch 5920 loss: 0.167
# Epoch 5930 loss: 0.167
# Epoch 5940 loss: 0.167
# Epoch 5950 loss: 0.167
# Epoch 5960 loss: 0.167
# Epoch 5970 loss: 0.167
# Epoch 5980 loss: 0.167
# Epoch 5990 loss: 0.167
# Epoch 6000 loss: 0.167
# Epoch 6010 loss: 0.167
# Epoch 6020 loss: 0.167
# Epoch 6030 loss: 0.167
# Epoch 6040 loss: 0.167
# Epoch 6050 loss: 0.167
# Epoch 6060 loss: 0.167
# Epoch 6070 loss: 0.167
# Epoch 6080 loss: 0.167
# Epoch 6090 loss: 0.167
# Epoch 6100 loss: 0.167
# Epoch 6110 loss: 0.167
# Epoch 6120 loss: 0.167
# Epoch 6130 loss: 0.167
# Epoch 6140 loss: 0.167
# Epoch 6150 loss: 0.167
# Epoch 6160 loss: 0.167
# Epoch 6170 loss: 0.167
# Epoch 6180 loss: 0.167
# Epoch 6190 loss: 0.167
# Epoch 6200 loss: 0.167
# Epoch 6210 loss: 0.167
# Epoch 6220 loss: 0.167
# Epoch 6230 loss: 0.167
# Epoch 6240 loss: 0.167
# Epoch 6250 loss: 0.167
# Epoch 6260 loss: 0.167
# Epoch 6270 loss: 0.167
# Epoch 6280 loss: 0.167
# Epoch 6290 loss: 0.167
# Epoch 6300 loss: 0.167
# Epoch 6310 loss: 0.167
# Epoch 6320 loss: 0.167
# Epoch 6330 loss: 0.167
# Epoch 6340 loss: 0.167
# Epoch 6350 loss: 0.167
# Epoch 6360 loss: 0.167
# Epoch 6370 loss: 0.167
# Epoch 6380 loss: 0.167
# Epoch 6390 loss: 0.167
# Epoch 6400 loss: 0.167
# Epoch 6410 loss: 0.167
# Epoch 6420 loss: 0.167
# Epoch 6430 loss: 0.167
# Epoch 6440 loss: 0.167
# Epoch 6450 loss: 0.167
# Epoch 6460 loss: 0.167
# Epoch 6470 loss: 0.167
# Epoch 6480 loss: 0.167
# Epoch 6490 loss: 0.167
# Epoch 6500 loss: 0.167
# Epoch 6510 loss: 0.167
# Epoch 6520 loss: 0.167
# Epoch 6530 loss: 0.167
# Epoch 6540 loss: 0.167
# Epoch 6550 loss: 0.167
# Epoch 6560 loss: 0.167
# Epoch 6570 loss: 0.167
# Epoch 6580 loss: 0.167
# Epoch 6590 loss: 0.167
# Epoch 6600 loss: 0.167
# Epoch 6610 loss: 0.167
# Epoch 6620 loss: 0.167
# Epoch 6630 loss: 0.167
# Epoch 6640 loss: 0.167
# Epoch 6650 loss: 0.167
# Epoch 6660 loss: 0.167
# Epoch 6670 loss: 0.167
# Epoch 6680 loss: 0.167
# Epoch 6690 loss: 0.167
# Epoch 6700 loss: 0.167
# Epoch 6710 loss: 0.167
# Epoch 6720 loss: 0.167
# Epoch 6730 loss: 0.167
# Epoch 6740 loss: 0.167
# Epoch 6750 loss: 0.167
# Epoch 6760 loss: 0.167
# Epoch 6770 loss: 0.167
# Epoch 6780 loss: 0.167
# Epoch 6790 loss: 0.167
# Epoch 6800 loss: 0.167
# Epoch 6810 loss: 0.167
# Epoch 6820 loss: 0.167
# Epoch 6830 loss: 0.167
# Epoch 6840 loss: 0.167
# Epoch 6850 loss: 0.167
# Epoch 6860 loss: 0.167
# Epoch 6870 loss: 0.167
# Epoch 6880 loss: 0.167
# Epoch 6890 loss: 0.167
# Epoch 6900 loss: 0.167
# Epoch 6910 loss: 0.167
# Epoch 6920 loss: 0.167
# Epoch 6930 loss: 0.167
# Epoch 6940 loss: 0.167
# Epoch 6950 loss: 0.167
# Epoch 6960 loss: 0.167
# Epoch 6970 loss: 0.167
# Epoch 6980 loss: 0.167
# Epoch 6990 loss: 0.167
# Epoch 7000 loss: 0.167
# Epoch 7010 loss: 0.167
# Epoch 7020 loss: 0.167
# Epoch 7030 loss: 0.167
# Epoch 7040 loss: 0.167
# Epoch 7050 loss: 0.167
# Epoch 7060 loss: 0.167
# Epoch 7070 loss: 0.167
# Epoch 7080 loss: 0.167
# Epoch 7090 loss: 0.167
# Epoch 7100 loss: 0.167
# Epoch 7110 loss: 0.167
# Epoch 7120 loss: 0.167
# Epoch 7130 loss: 0.167
# Epoch 7140 loss: 0.167
# Epoch 7150 loss: 0.167
# Epoch 7160 loss: 0.167
# Epoch 7170 loss: 0.167
# Epoch 7180 loss: 0.167
# Epoch 7190 loss: 0.167
# Epoch 7200 loss: 0.167
# Epoch 7210 loss: 0.167
# Epoch 7220 loss: 0.167
# Epoch 7230 loss: 0.167
# Epoch 7240 loss: 0.167
# Epoch 7250 loss: 0.167
# Epoch 7260 loss: 0.167
# Epoch 7270 loss: 0.167
# Epoch 7280 loss: 0.167
# Epoch 7290 loss: 0.167
# Epoch 7300 loss: 0.167
# Epoch 7310 loss: 0.167
# Epoch 7320 loss: 0.167
# Epoch 7330 loss: 0.167
# Epoch 7340 loss: 0.167
# Epoch 7350 loss: 0.167
# Epoch 7360 loss: 0.167
# Epoch 7370 loss: 0.167
# Epoch 7380 loss: 0.167
# Epoch 7390 loss: 0.167
# Epoch 7400 loss: 0.167
# Epoch 7410 loss: 0.167
# Epoch 7420 loss: 0.167
# Epoch 7430 loss: 0.167
# Epoch 7440 loss: 0.167
# Epoch 7450 loss: 0.167
# Epoch 7460 loss: 0.167
# Epoch 7470 loss: 0.167
# Epoch 7480 loss: 0.167
# Epoch 7490 loss: 0.167
# Epoch 7500 loss: 0.167
# Epoch 7510 loss: 0.167
# Epoch 7520 loss: 0.167
# Epoch 7530 loss: 0.167
# Epoch 7540 loss: 0.167
# Epoch 7550 loss: 0.167
# Epoch 7560 loss: 0.167
# Epoch 7570 loss: 0.167
# Epoch 7580 loss: 0.167
# Epoch 7590 loss: 0.167
# Epoch 7600 loss: 0.167
# Epoch 7610 loss: 0.167
# Epoch 7620 loss: 0.167
# Epoch 7630 loss: 0.167
# Epoch 7640 loss: 0.167
# Epoch 7650 loss: 0.167
# Epoch 7660 loss: 0.167
# Epoch 7670 loss: 0.167
# Epoch 7680 loss: 0.167
# Epoch 7690 loss: 0.167
# Epoch 7700 loss: 0.167
# Epoch 7710 loss: 0.167
# Epoch 7720 loss: 0.167
# Epoch 7730 loss: 0.167
# Epoch 7740 loss: 0.167
# Epoch 7750 loss: 0.167
# Epoch 7760 loss: 0.167
# Epoch 7770 loss: 0.167
# Epoch 7780 loss: 0.167
# Epoch 7790 loss: 0.167
# Epoch 7800 loss: 0.167
# Epoch 7810 loss: 0.167
# Epoch 7820 loss: 0.167
# Epoch 7830 loss: 0.167
# Epoch 7840 loss: 0.167
# Epoch 7850 loss: 0.167
# Epoch 7860 loss: 0.167
# Epoch 7870 loss: 0.167
# Epoch 7880 loss: 0.167
# Epoch 7890 loss: 0.167
# Epoch 7900 loss: 0.167
# Epoch 7910 loss: 0.167
# Epoch 7920 loss: 0.167
# Epoch 7930 loss: 0.167
# Epoch 7940 loss: 0.167
# Epoch 7950 loss: 0.167
# Epoch 7960 loss: 0.167
# Epoch 7970 loss: 0.167
# Epoch 7980 loss: 0.167
# Epoch 7990 loss: 0.167
# Epoch 8000 loss: 0.167
# Epoch 8010 loss: 0.167
# Epoch 8020 loss: 0.167
# Epoch 8030 loss: 0.167
# Epoch 8040 loss: 0.167
# Epoch 8050 loss: 0.167
# Epoch 8060 loss: 0.167
# Epoch 8070 loss: 0.167
# Epoch 8080 loss: 0.167
# Epoch 8090 loss: 0.167
# Epoch 8100 loss: 0.167
# Epoch 8110 loss: 0.167
# Epoch 8120 loss: 0.167
# Epoch 8130 loss: 0.167
# Epoch 8140 loss: 0.167
# Epoch 8150 loss: 0.167
# Epoch 8160 loss: 0.167
# Epoch 8170 loss: 0.167
# Epoch 8180 loss: 0.167
# Epoch 8190 loss: 0.167
# Epoch 8200 loss: 0.167
# Epoch 8210 loss: 0.167
# Epoch 8220 loss: 0.167
# Epoch 8230 loss: 0.167
# Epoch 8240 loss: 0.167
# Epoch 8250 loss: 0.167
# Epoch 8260 loss: 0.167
# Epoch 8270 loss: 0.167
# Epoch 8280 loss: 0.167
# Epoch 8290 loss: 0.167
# Epoch 8300 loss: 0.167
# Epoch 8310 loss: 0.167
# Epoch 8320 loss: 0.167
# Epoch 8330 loss: 0.167
# Epoch 8340 loss: 0.167
# Epoch 8350 loss: 0.167
# Epoch 8360 loss: 0.167
# Epoch 8370 loss: 0.167
# Epoch 8380 loss: 0.167
# Epoch 8390 loss: 0.167
# Epoch 8400 loss: 0.167
# Epoch 8410 loss: 0.167
# Epoch 8420 loss: 0.167
# Epoch 8430 loss: 0.167
# Epoch 8440 loss: 0.167
# Epoch 8450 loss: 0.167
# Epoch 8460 loss: 0.167
# Epoch 8470 loss: 0.167
# Epoch 8480 loss: 0.167
# Epoch 8490 loss: 0.167
# Epoch 8500 loss: 0.167
# Epoch 8510 loss: 0.167
# Epoch 8520 loss: 0.167
# Epoch 8530 loss: 0.167
# Epoch 8540 loss: 0.167
# Epoch 8550 loss: 0.167
# Epoch 8560 loss: 0.167
# Epoch 8570 loss: 0.167
# Epoch 8580 loss: 0.167
# Epoch 8590 loss: 0.167
# Epoch 8600 loss: 0.167
# Epoch 8610 loss: 0.167
# Epoch 8620 loss: 0.167
# Epoch 8630 loss: 0.167
# Epoch 8640 loss: 0.167
# Epoch 8650 loss: 0.167
# Epoch 8660 loss: 0.167
# Epoch 8670 loss: 0.167
# Epoch 8680 loss: 0.167
# Epoch 8690 loss: 0.167
# Epoch 8700 loss: 0.167
# Epoch 8710 loss: 0.167
# Epoch 8720 loss: 0.167
# Epoch 8730 loss: 0.167
# Epoch 8740 loss: 0.167
# Epoch 8750 loss: 0.167
# Epoch 8760 loss: 0.167
# Epoch 8770 loss: 0.167
# Epoch 8780 loss: 0.167
# Epoch 8790 loss: 0.167
# Epoch 8800 loss: 0.167
# Epoch 8810 loss: 0.167
# Epoch 8820 loss: 0.167
# Epoch 8830 loss: 0.167
# Epoch 8840 loss: 0.167
# Epoch 8850 loss: 0.167
# Epoch 8860 loss: 0.167
# Epoch 8870 loss: 0.167
# Epoch 8880 loss: 0.167
# Epoch 8890 loss: 0.167
# Epoch 8900 loss: 0.167
# Epoch 8910 loss: 0.167
# Epoch 8920 loss: 0.167
# Epoch 8930 loss: 0.167
# Epoch 8940 loss: 0.167
# Epoch 8950 loss: 0.167
# Epoch 8960 loss: 0.167
# Epoch 8970 loss: 0.167
# Epoch 8980 loss: 0.167
# Epoch 8990 loss: 0.167
# Epoch 9000 loss: 0.167
# Epoch 9010 loss: 0.167
# Epoch 9020 loss: 0.167
# Epoch 9030 loss: 0.167
# Epoch 9040 loss: 0.167
# Epoch 9050 loss: 0.167
# Epoch 9060 loss: 0.167
# Epoch 9070 loss: 0.167
# Epoch 9080 loss: 0.167
# Epoch 9090 loss: 0.167
# Epoch 9100 loss: 0.167
# Epoch 9110 loss: 0.167
# Epoch 9120 loss: 0.167
# Epoch 9130 loss: 0.167
# Epoch 9140 loss: 0.167
# Epoch 9150 loss: 0.167
# Epoch 9160 loss: 0.167
# Epoch 9170 loss: 0.167
# Epoch 9180 loss: 0.167
# Epoch 9190 loss: 0.167
# Epoch 9200 loss: 0.167
# Epoch 9210 loss: 0.167
# Epoch 9220 loss: 0.167
# Epoch 9230 loss: 0.167
# Epoch 9240 loss: 0.167
# Epoch 9250 loss: 0.167
# Epoch 9260 loss: 0.167
# Epoch 9270 loss: 0.167
# Epoch 9280 loss: 0.167
# Epoch 9290 loss: 0.167
# Epoch 9300 loss: 0.167
# Epoch 9310 loss: 0.167
# Epoch 9320 loss: 0.167
# Epoch 9330 loss: 0.167
# Epoch 9340 loss: 0.167
# Epoch 9350 loss: 0.167
# Epoch 9360 loss: 0.167
# Epoch 9370 loss: 0.167
# Epoch 9380 loss: 0.167
# Epoch 9390 loss: 0.167
# Epoch 9400 loss: 0.167
# Epoch 9410 loss: 0.167
# Epoch 9420 loss: 0.167
# Epoch 9430 loss: 0.167
# Epoch 9440 loss: 0.167
# Epoch 9450 loss: 0.167
# Epoch 9460 loss: 0.167
# Epoch 9470 loss: 0.167
# Epoch 9480 loss: 0.167
# Epoch 9490 loss: 0.167
# Epoch 9500 loss: 0.167
# Epoch 9510 loss: 0.167
# Epoch 9520 loss: 0.167
# Epoch 9530 loss: 0.167
# Epoch 9540 loss: 0.167
# Epoch 9550 loss: 0.167
# Epoch 9560 loss: 0.167
# Epoch 9570 loss: 0.167
# Epoch 9580 loss: 0.167
# Epoch 9590 loss: 0.167
# Epoch 9600 loss: 0.167
# Epoch 9610 loss: 0.167
# Epoch 9620 loss: 0.167
# Epoch 9630 loss: 0.167
# Epoch 9640 loss: 0.167
# Epoch 9650 loss: 0.167
# Epoch 9660 loss: 0.167
# Epoch 9670 loss: 0.167
# Epoch 9680 loss: 0.167
# Epoch 9690 loss: 0.167
# Epoch 9700 loss: 0.167
# Epoch 9710 loss: 0.167
# Epoch 9720 loss: 0.167
# Epoch 9730 loss: 0.167
# Epoch 9740 loss: 0.167
# Epoch 9750 loss: 0.167
# Epoch 9760 loss: 0.167
# Epoch 9770 loss: 0.167
# Epoch 9780 loss: 0.167
# Epoch 9790 loss: 0.167
# Epoch 9800 loss: 0.167
# Epoch 9810 loss: 0.167
# Epoch 9820 loss: 0.167
# Epoch 9830 loss: 0.167
# Epoch 9840 loss: 0.167
# Epoch 9850 loss: 0.167
# Epoch 9860 loss: 0.167
# Epoch 9870 loss: 0.167
# Epoch 9880 loss: 0.167
# Epoch 9890 loss: 0.167
# Epoch 9900 loss: 0.167
# Epoch 9910 loss: 0.167
# Epoch 9920 loss: 0.167
# Epoch 9930 loss: 0.167
# Epoch 9940 loss: 0.167
# Epoch 9950 loss: 0.167
# Epoch 9960 loss: 0.167
# Epoch 9970 loss: 0.167
# Epoch 9980 loss: 0.167
# Epoch 9990 loss: 0.167
# Emily: 0.346
# Frank: 0.338
